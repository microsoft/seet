# %%
# %matplotlib widget

from IPython.display import display, Markdown
import ipywidgets
import kiruna.sensitivity_analysis as sensitivity_analysis
import kiruna.visualization.sampler_visualization as sampler_visualization
import matplotlib.pyplot as plt
import numpy
import os
import pickle
import sys
sys.path.append("..")

import utils

text_widget = utils.get_path(show=True)
# Out:
# Text(value='.\\results\\.', description='Results:', placeholder="Default is '.'")

# %%
import importlib
import covariance_analysis_utils as cov_utils
importlib.reload(cov_utils);

# %%
pickle_file_name = text_widget.value
full_prefix_name = pickle_file_name.split(" dict.pkl")[0]

with open(pickle_file_name, 'rb') as file_stream:
    data_dictionary = pickle.load(file_stream)

plots = cov_utils.CreatePlots(data_dictionary)

# %%
plots.plot_results()
print(plots.psi_variance)
print(plots.position_variance)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# tensor(5.7631, grad_fn=<DivBackward0>)
# tensor([0.4675, 0.8647, 0.5640], grad_fn=<DivBackward0>)

# %%
plots = cov_utils.CreatePlots(data_dictionary)

# %%
plots.plot_results()
print(plots.psi_variance)
print(plots.position_variance)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# tensor(0.4523, grad_fn=<DivBackward0>)
# tensor([0.0635, 0.0585, 0.0768], grad_fn=<DivBackward0>)
